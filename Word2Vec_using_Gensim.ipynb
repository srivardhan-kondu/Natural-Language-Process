# %%
# !pip install gensim

# %%
import gensim

# %%
# !pip install --upgrade scipy
# Out:
# ...
#   Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
# Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlproject 0.0.1 requires sklearn, which is not installed.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.14.1 which is incompatible.

# %%
# !pip install --upgrade gensim
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.6 kB 1.4 MB/s eta 0:00:01
#      ---------------------------------------- 60.6/60.6 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#     --------------------------------------- 0.4/24.0 MB 13.9 MB/s eta 0:00:02
#    -- ------------------------------------- 1.6/24.0 MB 20.2 MB/s eta 0:00:02
#    -- ------------------------------------- 1.7/24.0 MB 21.3 MB/s eta 0:00:02
#    -- ------------------------------------- 1.7/24.0 MB 21.3 MB/s eta 0:00:02
#    -- ------------------------------------- 1.7/24.0 MB 21.3 MB/s eta 0:00:02
#    -- ------------------------------------- 1.7/24.0 MB 21.3 MB/s eta 0:00:02
#    -- ------------------------------------- 1.7/24.0 MB 21.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 2.6/24.0 MB 7.1 MB/s eta 0:00:04
# ...

# %%
# !pip uninstall scipy
# !pip install scipy

# %%
from gensim.models import Word2Vec,KeyedVectors

# %%
import gensim.downloder as api

# %%
wv=api.load('word2vec-google-news-300')
print(111)
